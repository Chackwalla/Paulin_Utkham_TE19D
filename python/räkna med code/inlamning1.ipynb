# %%
K = float(input("Give me Kelvin now: "))
C = K-273.15

print(f"{K} Kelvin is {C} Celcius")
# Out:
# 300.0 Kelvin is 26.850000000000023 Celcius

# %%
C = float(input("Give me Celcius now!: "))
K = K-273.15

print(f"{C} Celcious is {K} Kelvin")
# Out:
# 30.0 Celcious is 26.850000000000023 Kelvin

# %%
antalResor = float(input("Give me your amount of need for speed: "))
price = antalResor*30

print(f"This is how much it'll all cost: {price}")
# Out:
# This is how much it'll all cost: 150.0

# %%
antalResor = float(input("Give me your amount of need for speed: "))
price = antalResor*30

if price <= 774:
    print(f"This is how much it all will cost: {price}")

if price >= 775: 
    print(f"This is how much it all will cost: {price}, I recomend you buying the monthly pass")
# Out:
# This is how much it all will cost: 780.0, I recomend you buying the monthly pass
